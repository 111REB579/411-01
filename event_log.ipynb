# %% [markdown]
# <a href="https://colab.research.google.com/github/111REB579/411-01/blob/master/event_log.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
pd.set_option('display.max_rows', None)
data = pd.read_csv("event_log.csv") 
print(data)
# Out:
#                            Level  ...                                      Task Category
# Warning      16.09.2020 10:33:53  ...  The machine-default permission settings do not...
# Warning      16.09.2020 10:33:51  ...  The machine-default permission settings do not...
# Warning      16.09.2020 10:31:50  ...  The machine-default permission settings do not...
# Information  16.09.2020 10:24:20  ...  The start type of the Background Intelligent T...
# Information  16.09.2020 10:22:15  ...  The start type of the Background Intelligent T...
# Information  16.09.2020 10:17:30  ...  The start type of the Background Intelligent T...
# Warning      16.09.2020 10:14:15  ...  The application-specific permission settings d...
# Warning      16.09.2020 10:14:15  ...  The application-specific permission settings d...
# Warning      16.09.2020 10:14:09  ...  The application-specific permission settings d...
# ...
